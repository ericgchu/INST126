# %%
import pandas as pd

def main():
    
    # Parse database file as df
    df = pd.read_csv("/Users/francis/Desktop/nba.csv")
    
    # Greet User
    print("Hello, Welcome to the Functional NBA Player Database!")
    
    # Ask the user: "Which function would you like to run?" There are 4 options. 
    choice = int(input("Enter a number to execute an unique function; 1: Find a Player. 2: Get stats per position. 3: Retrieve a Player's stats. 4: Get Team Average: "))
    
    # Assume valid input
    # Depending on input, pass dataframe as parameter into chosen function
    if (choice == 1):
        find_a_player(df)
    if (choice == 2):
        get_player_position_stat(df)
    if (choice == 3):
        retrieve_player_stat(df)
    if (choice == 4):
        get_team_avg(df)
    
    
main()

playername = input("What player? (First name Last name)")
if playername == df.Player:
  statistic = str(input("Which statistic?  games played(G), minutes played(MP), player efficiency rating(PER), true shooting percentage(TS%), 3 point attempt rate(3PAr), free throw rate(FTr), offensive rebound percentage(ORB%), defensive rebound percentage(DRB%), total rebound percentage(TRB%), assist percentage(AST%), block percentage (BLK%), steal percentage(STL%), and turnover percentage(TOV%"))
  statistc = df.statist([])  ## Still working on this part
  result = ##Still working on this part as well
else:
  print("Invalid player name")

print("playername's statistic is result)

def games_played(df)

def true_shooting(df):
    
def three_point_attempt(df):
  
def minutes_played(df)

def player_efficiency_rating(df)

def freethrow_attempt(df)

def offensive_rebound(df)

def defensive_rebound(df)

def total_rebound(df)

def assist(df)

def block(df)

def steal(df)

def turnover(df)


def retrieve_player_stat(df):
##Still working on this part
